# %%
import ast
import json
import os
from pathlib import Path
import re
import shutil
from typing import Any, List
import warnings

import numpy as np
import pandas as pd


repo_dir = Path(os.path.abspath("")).parent
dss_dir = repo_dir / "resources"
eval_dir = repo_dir / "eval"

def process_num(value: Any):
    if isinstance(value, list) or isinstance(value, set) or isinstance(value, tuple):
        return [process_num(v) for v in value]
    elif isinstance(value, float):
        return round(round(value, 8), 4) # round by 8 to remove numerical inaccuracies, than by 4
    else:
        raise RuntimeError()

def process(value: str, metadata: str, label: bool):
    try:
        if value != "":
            value = ast.literal_eval(value)
            value = process_num(value)
            if isinstance(value, list) and len(value) > 0:
                value = np.array(value).squeeze()
                value[value == 0.] = 0.
                value = value.tolist()
                if len(value) == 1: 
                    value = value[0]
            if 'sorted' in metadata:
                value = sorted(value)
            value = str(value)
    except:
        value = str(value)

    if label:
        if value.startswith("re"):
            re_value = value.split("re")[1]
        else:
            re_value = re.escape(value)
    else:
        re_value = None

    return value, re_value

eval_metrics = []
for ds_dir in sorted(dss_dir.iterdir()):
    if not ds_dir.is_dir():
        continue

    abc_out_dir = ds_dir 
    abc_eval_dir = eval_dir / ds_dir.name 

    for sample in sorted(abc_out_dir.iterdir()):
        with open(sample / "input.txt") as f:
            text_batch = f.read()
        text_batch = text_batch.split("\n")
        
        solution_file = sample / "solution.txt"
        if not solution_file.is_file():
            warnings.warn("%s - No solution developed yet" % sample.name)
            with open(solution_file, 'w') as f:
                f.write("".join(["\n" for _ in range(len(text_batch) - 1)]))
            # continue

        metadata_file = sample / "metadata.txt"
        metadata_batch = ["" for _ in range(len(text_batch))] 
        if metadata_file.is_file():
            with open(metadata_file) as f:
                metadata_subset = f.read().split("\n")
            for i, val in enumerate(metadata_subset):
                metadata_batch[i] = val

        with open(solution_file) as f:
            solution_batch = f.read()
            solution_batch = solution_batch.split("\n")

        assert len(solution_batch) == len(text_batch), sample
        assert len(solution_batch) == len(metadata_batch), sample

        for i, (text, solution, metadata) in enumerate(zip(text_batch, solution_batch, metadata_batch)):
            response_dir = abc_eval_dir / sample.name / str(i)

            eval_sample = {
                'ds': ds_dir.name,
                'id': sample.name,
                "question-idx": i,
                "question": text,
                'label': solution
            }

            if not response_dir.is_dir():
                warnings.warn("%s: %s - Not generated yet!" % (sample.name, i))

                eval_sample.update({
                    'failed': True,
                    'predicted': '',
                })

            else:
                eval_sample['failed'] = (response_dir / "exception.txt").is_file()

                if not eval_sample['failed']:
                    with open(response_dir / "result.txt") as f:
                        eval_sample['predicted'] = f.read()
                else:
                    eval_sample['predicted'] = ""

                try: 
                    predicted = ast.literal_eval(eval_sample['predicted'])
                    if isinstance(predicted, tuple):
                        eval_sample['predicted'] = str(list(predicted))
                except:
                    pass

                eval_sample['predicted'], _ = process(eval_sample['predicted'], metadata=metadata, label=False)
 
            eval_sample['label'], eval_sample['re_label'] = process(eval_sample['label'], metadata=metadata, label=True)
            # if eval_sample['predicted'] != eval_sample['label']:
            #     shutil.rmtree(response_dir)

            eval_metrics.append(eval_sample)

df = pd.DataFrame(eval_metrics)
# df['correct'] = (df['predicted'] == df['label']) & ~df['failed']
df['correct'] = (df.apply(lambda r: re.match(r['re_label'], r['predicted']) is not None, axis=1)) & ~df['failed']
del df['re_label']

if len(eval_sample['predicted']) > 100:
    eval_sample['predicted'] = eval_sample['predicted'][:100] + "..."

# %%
# df = pd.read_csv(resources_dir / "eval/eval.csv")
df_i = df.set_index(['ds', 'id', 'question-idx'])
print('correct:', df_i['correct'].sum())
print('questions:', (df_i['label'] != 'X').sum())
df_i.style.set_properties(subset=['question'], **{'width': '600px'})
# df_i.to_csv(repources_dir / "eval/eval.csv")
pd.options.display.max_rows = 111
df_i
# Out:
# correct: 0
# questions: 111
#                                                                                                      question  \
# ds         id                                 question-idx
# abc        00000002                           0                                       How wide is the object?
#                                               1                       What is the total height of the object?
#                                               2             How many holes are present around the object e...
#                                               3             what is the depth of the thru-hole visible on ...
#                                               4             what is the radius of the through-hole visible...
#                                               5             What is the minimal distance between the cente...
#            00000013                           0                          How many holes does the object have?
#                                               1                  What different diameters do the holes have?
#                                               2             What is the diameter of the largest hole on th...
#                                               3             What is the depth of the hole with the smalles...
#                                               4             How many holes are visible from the right side...
#            00000024                           0             What are the center coordinates of all holes v...
#                                               1                                       How deep are the holes?
#                                               2                 How many holes are present on the cad object?
#                                               3                   What is the width and height of the object?
#            00000057                           0             What are the overall dimensions (width, depth ...
#                                               1             What is the diameter of the individual holes o...
#                                               2             What is the maximal distance between the cente...
#                                               3             What is the thickness of the material used in ...
#                                               4             What is the minimal distance from the edge of ...
#                                               5                              What is the radius of the bevel?
#                                               6             What is the maximal distance between two holes...
#            00000115                           0              What is the outer diameter of the circular base?
#                                               1             How many radial slots are cut into the top sur...
#                                               2             What is the inner diameter of the threaded hol...
#                                               3             What are the different radii of the holes loca...
#                                               4                       What is the total height of the object?
#            00000124                           0                     how many holes are visible from the left?
#                                               1             There are holes with two different radii in th...
#                                               2             What are the center positions of the holes wit...
#                                               3                               What is the center of the cone?
#                                               4             What is the size of the ring around the cone v...
#            00000179                           0             What is height of the part looking like a shaf...
#                                               1               How many mounting holes are present on the top?
#                                               2             What is the diameter of the mounting holes pre...
#                                               3             What is the position of the two rectangular po...
#                                               4                 What is the diameter of the largest cylinder?
#            00000180                           0                            What is the diameter of the shaft?
#                                               1                              What is the radius of the holes?
#                                               2                            How deep are the holes on the top?
#                                               3                        How many holes are present on the top?
#                                               4             How high is the object without the height of t...
#                                               5                      What is the radius of the adapter plate?
#            00000181                           0                    How wide is the gear visible from the top?
#                                               1             What is the diameter of the through hole shown...
#                                               2                          How many holes does the object have?
#                                               3                                       How high is the object?
#                                               4             What is the size of the rectangular slot visib...
#                                               5                      How many cutouts are in the bottom side?
#            00000182                           0                                How many holes has the object?
#                                               1                     What is the location of the largest hole?
#                                               2                    What are the different radii of the holes?
#                                               3             How deep are the holes with a diameter of 5.5 mm?
# industrial 15000                              0             What are the heights of the standoffs with a h...
#                                               1             How large are the uniquely different diameters...
#                                               2               How many standoffs are visible from the bottom?
#                                               3             What is the radius of the tru-hole visible fro...
#                                               4                    How many holes are visible from the right?
#                                               5             What are the unique radii of the holes visible...
#                                               6             What is the center of the head gasket shown fr...
#                                               7             What is the size of all cooling fins visible f...
#                                               8             How many holes with a radius between 4 and 6 m...
#            3Kant                              0                           What is the center of the nut hole?
#                                               1             What is the diameter of the holes visible from...
#                                               2                 How deep is the tube visible from the bottom?
#                                               3             How wide are the holes with a ring visible fro...
#                                               4                          How many holes does the object have?
#                                               5                             How wide is the slot on the back?
#            Assembly                           0             How many blind holes are visible from the bottom?
#                                               1             How many holes visible from the bottom have a ...
#                                               2             What are the positions of the holes visible fr...
#                                               3             What is the radius of the circular protrusion ...
#                                               4             How many holes with a bevel are there in the t...
#                                               5             What is the height of the rectangular protrusi...
#                                               6             What are the different radii the holes in the ...
#                                               7                 What is the size of the octagonal base plate?
#                                               8                                How wide is the entire object?
#                                               9                       What is the radius of the biggest hole?
#            ATI-9150-RC-151                    0             How many hexagonal screws are visible from the...
#                                               1             What is the position of the hole visible from ...
#                                               2             What are the center positions of the grids in ...
#                                               3             What radius have the holes visible from the back?
#                                               4             How many screws are required to assemble the o...
#                                               5             What are the extents of the rectangular part v...
#                                               6             What is the center of the rectangular indentat...
#                                               7             What is the width and height of the rectangula...
#                                               8             How many hexagonal screw heads are visible fro...
#                                               9                                          How wide is the rod?
#            clutch housing                     0                          How many holes does the object have?
#                                               1             What is the radius of the biggest hole visible...
#                                               2                               What is the size of the object?
#                                               3                       What different radii do the holes have?
#            Gehaeuse                           0             How many mounting holes are visible from the b...
#                                               1             What is the depth of the mounting holes visibl...
#                                               2                        What is the radius of the semicircles?
#                                               3                             How many semicircles are present?
#                                               4             What is the diameter of the holes visible from...
#                                               5             What is the size of the rectangular inside of ...
#            SCHUNK-0310940 EGP 40-N-N-B,00ohne 0             What is the center position of the power conne...
#                                               1             How many holes with a diameter smaller than 3 ...
#                                               2             What different radii do the holes on the botto...
#                                               3             How big are the rectangular pins that are visi...
#                                               4                             What is the center of the object?
#                                               5                           How wide is the logo on the bottom?
#                                               6               How many screw heads are visible from the left?
#                                               7                         How many screws does the object have?
#            zusammenbau                        0                          How many holes does the object have?
#                                               1             How far apart are the two legs visible from th...
#                                               2             What is the radius of the inner cylinder on th...
#                                               3                   What diameter have the holes on the bottom?
#                                               4                     How many holes are visible on the bottom?
#
#                                                                                                         label  \
# ds         id                                 question-idx
# abc        00000002                           0                                                        0.0812
#                                               1                                                        0.0301
#                                               2                                                     re(19|20)
#                                               3                                                         0.046
#                                               4                                                        0.0032
#                                               5                                                        0.0088
#            00000013                           0                                                     re(12|13)
#                                               1                                      [0.0043, 0.0063, 0.0127]
#                                               2                                                        0.0063
#                                               3                                                        0.0095
#                                               4                                                             5
#            00000024                           0             [[0.0394, 0.2099, 0.0033], [0.211, 0.03, 0.0033]]
#                                               1                                              [0.0166, 0.0166]
#                                               2                                                       re(2|3)
#                                               3                                              [0.2535, 0.0266]
#            00000057                           0                                          [0.095, 0.171, 0.05]
#                                               1                                      [0.01, 0.01, 0.01, 0.01]
#                                               2                                                        0.0893
#                                               3                                                         0.003
#                                               4                                                re(0.005|0.01)
#                                               5                                                         0.005
#                                               6                                                         0.059
#            00000115                           0                                                        0.0161
#                                               1                                                            11
#                                               2                                                        0.0055
#                                               3                                      [0.0016, 0.0026, 0.0027]
#                                               4                                                        0.0104
#            00000124                           0                                                            11
#                                               1             re(0.0063|\[0.0063, 0.0063, 0.0063, 0.0063, 0....
#                                               2             [[0.0125, 0.0144, -0.0479], [0.0124, -0.0165, ...
#                                               3                               re\[(0.0218|0.0343), 0.0, 0.0\]
#                                               4                                                        0.0341
#            00000179                           0                                                        0.0152
#                                               1                                                             6
#                                               2              [0.0024, 0.0024, 0.0024, 0.0024, 0.0024, 0.0024]
#                                               3              [[0.0, 0.0, -0.001], [-0.0087, 0.0098, -0.0018]]
#                                               4                                                        0.0369
#            00000180                           0                                                         0.005
#                                               1                              [0.0013, 0.0013, 0.0013, 0.0013]
#                                               2                              [0.0045, 0.0045, 0.0045, 0.0045]
#                                               3                                                             4
#                                               4                                                         0.045
#                                               5                                                         0.011
#            00000181                           0                                                        0.0174
#                                               1                                                         0.005
#                                               2                                                             2
#                                               3                                                         0.031
#                                               4                                      [0.0056, 0.0024, 0.0126]
#                                               5                                                             2
#            00000182                           0                                                             9
#                                               1                                     [-0.0415, -0.0395, 0.051]
#                                               2                                       [0.0016, 0.0027, 0.011]
#                                               3                                                         0.034
# industrial 15000                              0             [0.0045, 0.0045, 0.0166, 0.0186, 0.0337, 0.034...
#                                               1                                        [0.006, 0.0068, 0.008]
#                                               2                                                             7
#                                               3                                                        0.0205
#                                               4                                                             7
#                                               5                              [0.0021, 0.0025, 0.0034, 0.0035]
#                                               6                                         [0.212, 0.143, -0.06]
#                                               7                                         [0.086, 0.131, 0.112]
#                                               8                                                             4
#            3Kant                              0                                            [0.0035, 0.007, 0]
#                                               1                              [0.0052, 0.0052, 0.0052, 0.0052]
#                                               2                                                        0.0565
#                                               3                              [0.0086, 0.0086, 0.0086, 0.0086]
#                                               4                                                       re(7|8)
#                                               5                                                        0.0037
#            Assembly                           0                                                             5
#                                               1                                                             8
#                                               2             [[-0.0352, -0.01, 0.005], [-0.0352, 0.01, 0.00...
#                                               3                                                          0.03
#                                               4                                                            10
#                                               5                                        [0.0382, 0.043, 0.044]
#                                               6             [0.0008, 0.001, 0.0016, 0.002, 0.0021, 0.0022,...
#                                               7                                          [0.084, 0.084, 0.01]
#                                               8                                                        0.1466
#                                               9                                                        0.0055
#            ATI-9150-RC-151                    0                                                             6
#                                               1                                         [0.0, -0.02, -0.0038]
#                                               2             re\[\[0.0, -(0.0395|0.0382), -0.0556\], \[0.0,...
#                                               3                                      [0.0042, 0.0042, 0.0127]
#                                               4                                                            16
#                                               5             re(\[0.0094, 0.0135, 0.03969\]|\[0.0188, 0.027...
#                                               6                                    [-0.0036, 0.0008, -0.1901]
#                                               7                                              [0.0277, 0.0437]
#                                               8                                                             2
#                                               9                                                         0.016
